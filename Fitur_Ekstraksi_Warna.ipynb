# %% [markdown]
# <a href="https://colab.research.google.com/github/mabdullahaziz12/UAS_Visi_Komputer/blob/main/Fitur_Ekstraksi_Warna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#impor library
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib.pyplot as plt
import glob

from skimage.color import rgb2gray
from skimage.feature import local_binary_pattern

# %%
#Membaca gambar dari
img = plt.imread('1.jpg')

#Membuat plot Untuk histogram warna
fig, axs = plt.subplots(1, 3, figsize=(10, 5))
for i, color in enumerate(['red', 'green', 'blue']):
    axs[i].hist(img[..., i].ravel(), bins=256, color=color)
    axs[i].set_xlim([0, 256])
    axs[i].set_ylim([0, 10000])
    axs[i].set_title(color.upper())


#Menampilkan histogram warna
plt.show()
